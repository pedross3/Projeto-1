# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## PEDRO DOS SANTOS E SILVA
# ___

# %% [markdown]
# ## Quão díspar é a distribuição de informação no Brasil?

# %% [markdown]
# ___
# ## Introdução
#
# A minha análise pretende evidenciar a desigualdade na imersão social no mundo tecnológico dos dados, num mundo que, hoje, é capaz de mover o mundo da informação.
#
# Descreva aqui o que pretende analisar!
# --CRIAR VARIÁVEL RENDAS RELATIVAS
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados: Adicionar relatividade nas respostas como uma variável quantitativa

# %%
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from numpy import arange
import os

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Dell\Documents\2A\Dados\Projeto1

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
#pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
dados = pd.read_csv("PES2015.csv", sep=";")
#dados = pd.read_excel("PES2015.xlsx")

# %%
dados = dados.loc[:,["UF","V9532","V06111","V06112","V061113","V061114","V061115","V061116"]]

# %%
dados.UF = dados.UF.astype('category')
#dados.V9532 = dados.V9532.astype('category')
dados.V06111 = dados.V06111.astype('category')
dados.V06112 = dados.V06112.astype('category')
dados.V061113 = dados.V061113.astype('category')
dados.V061114 = dados.V061114.astype('category')
dados.V061115 = dados.V061115.astype('category')
dados.V061116 = dados.V061116.astype('category')

# %%
evc = dados.V06111.value_counts().reindex(['Sim','Não'])

# %%
dados.V06111.cat.categories = (['Sim','Não'])
dados.V06112.cat.categories = (['Sim','Não'])
dados.V061113.cat.categories = (['Sim','Não'])
dados.V061114.cat.categories = (['Sim','Não'])
dados.V061115.cat.categories = (['Sim','Não'])
dados.V061116.cat.categories = (['Sim','Não'])

# %%
dados.UF.cat.categories = (['Rondônia', 'Acre', 'Amazonas', 
                               'Roraima', 'Pará', 'Amapá', 
                               'Tocantins', 'Maranhão', 'Piauí', 
                               'Ceará','Rio Grande do Norte', 'Paraíba', 
                               'Pernambuco', 'Alagoas', 'Sergipe', 
                               'Bahia', 'Minas Gerais', 'Espírito Santo', 
                               'Rio de Janeiro', 'São Paulo', 'Paraná', 
                               'Santa Catarina', 'Rio Grande do Sul', 'Mato Grosso do Sul', 
                               'Mato Grosso', 'Goiás','Distrito Federal'])

# %%
ct = dados.UF[dados.V06111 == 'Sim'].value_counts()
ct.plot(kind='pie', colors=('salmon', 'cyan'), autopct="%0.2f",legend=False, subplots = True, figsize=(15,15))
plt.title('Parcela da população que obteve acesso a Internet')

# %%
ct = dados.UF[dados.V06112 == 'Sim'].value_counts()
ct.plot(kind='pie', colors=('blue', 'cyan'), autopct="%0.2f",legend=False, subplots = True, figsize=(15,15))
plt.title('Parcela da população que obteve acesso a Internet microcomp')

# %%
ct = dados.UF[dados.V061114 == 'Sim'].value_counts()
ct.plot(kind='pie', colors=('salmon', 'cyan'), autopct="%0.2f",legend=False, subplots = True, figsize=(15,15))
plt.title('Parcela da população que obteve acesso a Internet celular')

# %%
ct = dados.UF[dados.V061115 == 'Sim'].value_counts()
ct.plot(kind='pie', colors=('black', 'cyan'), autopct="%0.2f",legend=False, subplots = True, figsize=(15,15))
plt.title('Parcela da população que obteve acesso a Internet tablet')

# %%
ct = dados.UF[dados.V061116 == 'Sim'].value_counts()
ct.plot(kind='pie', colors=('magenta', 'cyan'), autopct="%0.2f",legend=False, subplots = True, figsize=(15,15))
plt.title('Parcela da população que obteve acesso a Internet TV')

# %%
ct = pd.crosstab(dados.UF,dados.V06111, normalize = True)

# %%
#plot.set_ylim([0, 100])
ct.plot(kind='bar',stacked = True)*100
plt.ylabel('Freq.Relativa (em %)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-4588b8c86d04> in <module>()
#       1 #plot.set_ylim([0, 100])
# ----> 2 ct.plot(kind='bar',stacked = True)*100
#       3 plt.ylabel('Freq.Relativa (em %)')
#
# TypeError: unsupported operand type(s) for *: 'AxesSubplot' and 'int'

# %%
ct_1516 = pd.crosstab(dados.UF, dados.V061116)

# %%
#Criar relatividade na renda: --9532
cel2015 = dados.V06112

# %%
dados.loc[(dados.UF=='Rondônia') | (dados.UF=='Acre') | (dados.UF=='Amazonas') | (dados.UF=='Roraima') | (dados.UF=='Pará') | (dados.UF=='Amapá') | (dados.UF=='Tocantins'),'Regiao'] = 'Norte'
dados.loc[(dados.UF=='Maranhão') | (dados.UF=='Piaui') | (dados.UF=='Caerá') | (dados.UF=='Rio Grande do Norte') | (dados.UF=='Paraíba') | (dados.UF=='Pernambuco') | (dados.UF=='Alagoas') | (dados.UF=='Sergipe') | (dados.UF=='Bahia'),'Regiao'] = 'Nordeste'
dados.loc[(dados.UF=='Minas Gerais') | (dados.UF=='Espirito Santo') | (dados.UF=='Rio de Janeiro') | (dados.UF=='São Paulo'),'Regiao'] = 'Sudeste'
dados.loc[(dados.UF=='Paraná') | (dados.UF=='Santa Catarina') | (dados.UF=='Rio Grande do Sul'),'Regiao'] = 'Sul'
dados.loc[(dados.UF=='Mato Grosso do Sul') | (dados.UF=='Mato Grosso') | (dados.UF=='Goiás') | (dados.UF=='Distrito Federal'),'Regiao'] = 'Centroeste'

# %%
ct=pd.crosstab(dados.UF, dados.V06111, rownames=['ESTADO'], colnames=['Acessou em algum local'],normalize=True)*100
ct=ct.round(decimals=1)

# %%
ct=pd.crosstab(dados.UF, dados.V06112, rownames=['ESTADO'], colnames=['Acesso por meio de um microcomputador'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct.plot(kind='bar',stacked = False)
plt.ylabel('Freq.Relativa (em %)')
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dados.UF, dados.V06111, rownames=['ESTADO'], colnames=['Acesso por meio de um celular'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct.plot(kind='bar',stacked = False)
plt.ylabel('Freq.Relativa (em %)')
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dados.UF, dados.V06111, rownames=['ESTADO'], colnames=['Acesso por meio de um tablet '],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct.plot(kind='bar',stacked = False)
plt.ylabel('Freq.Relativa (em %)')
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dados.UF, dados.V06111, rownames=['ESTADO'], colnames=['Acesso pela TV'],normalize=True)*100
ct=ct.round(decimals=1)
plot = ct.plot(kind='bar',stacked = False)
#plot.set_ylim([0, 100])
plt.ylabel('Freq.Relativa (em %)')
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dados.V06111, dados.UF, rownames=['Acesso por qualquer outro meio'],margins = True, colnames=['ESTADO'],normalize=True)*100
ct=ct.round(decimals=1)
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %%
ct=pd.crosstab(dados.V06111, dados.V9532, rownames=['ESTADO'], colnames=['Acesso por qualquer outro meio'],normalize=True)*100
ct=ct.round(decimals=1)
#plot =ct.plot.hist(normed=1, figsize=(6, 6), alpha=0.5)
#plt.ylabel('Freq.Relativa (em %)')

# %%
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']
#dados.columns = ['Unidade da Federação', 'Acessou internet em algum local', 'Acessou internet através de microcomputador','Acessou internet através de celular','Acessou internet através de tablet','Acessou internet através de TV','Acessou internet através de outro equipamento']

# %% [markdown]
# ___
# ## Conclusão
